# %% [markdown]
# # Create Dataset using API
#
# In this notebook, we'll go across the steps to access a website's information using its API.
#
# We'll use the Twitch API provided by Free Code Camp https://wind-bow.glitch.me/, which makes the API use very easy and simple, to access a list of channels and its information.

# %% [markdown]
# ## Import Libraries
# We will use three major libraries for this project. Numpy which makes array handling very efficient and quick, Pandas to handle the datsets, and requests to get the data from an API

# %%
# Import necessary libraries
import pandas as pd
import requests
import json

# %% [markdown]
# ## Understand the API
# Let's first understand what data is available through the API. We understand this with the help of freecodecamp channel.

# %%
url = "https://wind-bow.glitch.me/twitch-api/channels/freecodecamp"
JSONContent = requests.get(url).json()
content = json.dumps(JSONContent, indent = 4,sort_keys=True)
print(content)
# Out:
# {
#     "_id": 79776140,
#     "_links": {
#         "chat": "https://api.twitch.tv/kraken/chat/freecodecamp",
#         "commercial": "https://api.twitch.tv/kraken/channels/freecodecamp/commercial",
#         "editors": "https://api.twitch.tv/kraken/channels/freecodecamp/editors",
#         "features": "https://api.twitch.tv/kraken/channels/freecodecamp/features",
#         "follows": "https://api.twitch.tv/kraken/channels/freecodecamp/follows",
#         "self": "https://api.twitch.tv/kraken/channels/freecodecamp",
#         "stream_key": "https://api.twitch.tv/kraken/channels/freecodecamp/stream_key",
#         "subscriptions": "https://api.twitch.tv/kraken/channels/freecodecamp/subscriptions",
#         "teams": "https://api.twitch.tv/kraken/channels/freecodecamp/teams",
#         "videos": "https://api.twitch.tv/kraken/channels/freecodecamp/videos"
#     },
#     "background": null,
#     "banner": null,
#     "broadcaster_language": "en",
#     "created_at": "2015-01-14T03:36:47Z",
#     "delay": null,
#     "display_name": "FreeCodeCamp",
#     "followers": 11771,
#     "game": "Creative",
#     "language": "en",
#     "logo": "https://static-cdn.jtvnw.net/jtv_user_pictures/freecodecamp-profile_image-d9514f2df0962329-300x300.png",
#     "mature": false,
#     "name": "freecodecamp",
#     "partner": false,
#     "profile_banner": "https://static-cdn.jtvnw.net/jtv_user_pictures/freecodecamp-profile_banner-6f5e3445ff474aec-480.png",
#     "profile_banner_background_color": null,
#     "status": "Some GoLang Today #go #golang #youtube",
#     "updated_at": "2018-09-20T22:58:21Z",
#     "url": "https://www.twitch.tv/freecodecamp",
#     "video_banner": "https://static-cdn.jtvnw.net/jtv_user_pictures/freecodecamp-channel_offline_image-b8e133c78cd51cb0-1920x1080.png",
#     "views": 216347
# }

# %% [markdown]
# We can see we have a lot of useful information here. We can use '_id', display_name', 'status', 'followers', and 'views' and compile this data together in a dataset.

# %% [markdown]
# ## Create the dataset

# %%
# List of channels we want to access
channels = ["ESL_SC2", "OgamingSC2", "cretetion", "freecodecamp", "storbeck", "habathcx", "RobotCaleb", "noobs2ninjas",
            "ninja", "shroud", "Dakotaz", "esltv_cs", "pokimane", "tsm_bjergsen", "boxbox", "wtcn", "a_seagull",
           "kinggothalion", "amazhs", "jahrein", "thenadeshot", "sivhd", "kingrichard"]

channels_list = []
# For each channel, we access its information through its API
for channel in channels:
    JSONContent = requests.get("https://wind-bow.glitch.me/twitch-api/channels/" + channel).json()
    channels_list.append([JSONContent['_id'], JSONContent['display_name'], JSONContent['status'],
                         JSONContent['followers'], JSONContent['views']])

# %% [markdown]
# We have all the information inside a list and now we can create a dataset out of it.

# %%
dataset = pd.DataFrame(channels_list)
dataset.sample(5)
# Out:
#            0             1                                                  2  \
# 2   90401618     cretetion                    Logging some Miles With My Pack
# 15  51950404          wtcN  Bıktım başlık yazmaktan | sümüklü | instagram....
# 5    6726509      habathcx                                Massively Effective
# 21  27686136         SivHD  Siv HD messing around in WoW. the original FAM...
# 7   82534701  noobs2ninjas  Doing some work and felt like streaming. Progr...
#
#          3         4
# 2     2812     37083
# 15  834344  35332694
# 5       24      2622
# 21  993961  37815131
# 7      974     55127

# %% [markdown]
# Our dataset is ready but we can see a couple of problems here. Firstly, the headings are not representative of the data the column contains and secondly, there may be places which are empty.

# %%
dataset.columns = ['Id', 'Name', 'Status', 'Followers', 'Views']
dataset.dropna(axis = 0, how = 'any', inplace = True)
dataset.index = pd.RangeIndex(len(dataset.index))
dataset
# Out:
#           Id           Name  \
# 0   30220059        ESL_SC2
# 1   71852806     OgamingSC2
# 2   90401618      cretetion
# 3   79776140   FreeCodeCamp
# 4    6726509       habathcx
# 5   54925078     RobotCaleb
# 6   82534701   noobs2ninjas
# 7   19571641          Ninja
# 8   37402112         shroud
# 9   39298218        dakotaz
# 10  31239503       ESL_CSGO
# 11  44445592       pokimane
# 12  38421618   TSM_Bjergsen
# 13  38881685         boxbox
# 14  51950404           wtcN
# 15  19070311      A_Seagull
# 16  43830727  KingGothalion
# 17  43356746         AmazHS
# 18   6768122        Jahrein
# 19  21130533       Nadeshot
# 20  27686136          SivHD
# 21  66691674    KingRichard
#
#                                                Status  Followers      Views
# 0   RERUN: ShoWTimE vs. GuMiho [PvT] - Group D - I...     233265   75380804
# 1                           Olimoleague Weekly  #134       79265   38973783
# 2                     Logging some Miles With My Pack       2812      37083
# 3              Some GoLang Today #go #golang #youtube      11771     216347
# 4                                 Massively Effective         24       2622
# 5                                            Sabering         35       6684
# 6   Doing some work and felt like streaming. Progr...        974      55127
# 7   Duos with Travis Scott!  See how you could squ...   11343822  320594181
# 8                        gaminxS @Shroud for updates!    4352191  206944462
# 9           TSM Dakotaz - instagram/twitter: @dakotaz    2625586   59728959
# 10                           RERUN: IEM Shanghai 2018    2475125  296624596
# 11  See you guys soon! Follow my twitter & insta f...    2170913   43709758
# 12                 Monday stream as per usuallllllll!    1440737   91181335
# 13          Mr. Challenger Climb I don't FEel so good    1389852   83498885
# 14  Bıktım başlık yazmaktan | sümüklü | instagram....     834344   35332694
# 15                                               cozy     864185   24793514
# 16                                  Raid. Day. Today.     875741   34100062
# 17  ✧AMAZ✧ It's me! =D | !MTGA #sponsored , Ravnic...     894551   93073898
# 18  60 Parsecs uzay versiyonu | instagram.com/jahr...     935101   36168882
# 19               The Return to Fortnite | 100 Thieves     948418   42710352
# 20  Siv HD messing around in WoW. the original FAM...     993961   37815131
# 21  Fall Skirmish Practice #bushbandits @KingRicha...    1075328   17037876

# %% [markdown]
# ## Export the dataset
# Our complete dataset is now ready to be exported into a .csv file

# %%
dataset.to_csv("Dataset.csv", index = False)

# %% [markdown]
# Finally, our dataset is now ready and is available as the file 'Dataset.csv'. We can use similar procedure to access information from any site that provides the option to access its information through its API.
